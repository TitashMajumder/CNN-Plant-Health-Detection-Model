# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator # type: ignore
from tensorflow.keras import layers, models # type: ignore
from tensorflow.keras.models import Model, load_model # type: ignore
import matplotlib.pyplot as plt
import os
import json
from PIL import Image
import shutil
from pathlib import Path

# %%
print("--- GPU Detection Status ---")
print(tf.config.list_physical_devices('GPU'))
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# --- GPU Detection Status ---
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Num GPUs Available:  1

# %%
source_dirs = r'C:\NEWHELPTHEGREEN\health_classifier'

# %%
#Step 3: Data generators with augmentations
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # type: ignore

image_size = 128
batch_size = 8
train_dir = 'health_classifier/train'
val_dir = 'health_classifier/val'

# --- 1. Define Augmentation without validation_split ---
train_datagen = ImageDataGenerator(
    rescale=1./255,
    brightness_range=[0.8, 1.2],
    channel_shift_range=0.2,
    zoom_range=0.3,
    rotation_range=30,
    horizontal_flip=True,
    vertical_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    fill_mode='nearest'
)

# --- 2. Define Validation Generator (Only Rescaling) ---
val_datagen = ImageDataGenerator(rescale=1./255) 

# --- 3. Create Training Generator ---
train_gen = train_datagen.flow_from_directory(
    train_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical',
)

# --- 4. Create Validation Generator ---
val_gen = val_datagen.flow_from_directory(
    val_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical',
)

num_classes = train_gen.num_classes

print(f"Number of classes detected: {num_classes}")
print(f"Classes found by generator: {train_gen.class_indices}")
# Out:
# Found 5012 images belonging to 2 classes.
# Found 1076 images belonging to 2 classes.
# Number of classes detected: 2
# Classes found by generator: {'diseased': 0, 'healthy': 1}

# %%
# Count samples per class
total_diseased = len(os.listdir('health_classifier/train/diseased'))
total_healthy = len(os.listdir('health_classifier/train/healthy'))
total_samples = total_diseased + total_healthy

print(f"Diseased samples: {total_diseased}")
print(f"Healthy samples: {total_healthy}")
print(f"Total samples: {total_samples}")

# Calculate weights (give more weight to underrepresented class)
weight_diseased = total_samples / (2 * total_diseased)
weight_healthy = total_samples / (2 * total_healthy)

class_weights = {
    0: weight_diseased,    # diseased (usually smaller)
    1: weight_healthy      # healthy
}

print(f"\nClass weights:")
print(f"  Diseased: {weight_diseased:.4f}")
print(f"  Healthy: {weight_healthy:.4f}")
# Out:
# Diseased samples: 2940
# Healthy samples: 2072
# Total samples: 5012
#
# Class weights:
#   Diseased: 0.8524
#   Healthy: 1.2095

# %%
import keras_tuner as kt
from tensorflow.keras.optimizers import Adam # type: ignore
from tensorflow.keras.layers import BatchNormalization # type: ignore
from tensorflow.keras import layers, models # type: ignore
import json

# Define the model architecture for hyperparameter tuning
def build_model(hp):
    model = models.Sequential()

    # --- Conv Block 1 ---
    model.add(layers.Conv2D(
        filters=hp.Int('conv_1_filters', 32, 128, step=32),
        kernel_size=(3, 3),
        activation='relu',
        input_shape=(image_size, image_size, 3)
    ))
    model.add(BatchNormalization()) 
    model.add(layers.MaxPooling2D(2, 2))
    
    # --- Conv Block 2 ---
    model.add(layers.Conv2D(
        filters=hp.Int('conv_2_filters', 64, 256, step=64),
        kernel_size=(3, 3),
        activation='relu'
    ))
    model.add(BatchNormalization())
    model.add(layers.MaxPooling2D(2, 2))
    
    # --- Conv Block 3 ---
    model.add(layers.Conv2D(
        filters=hp.Int('conv_3_filters', 128, 512, step=128),
        kernel_size=(3, 3),
        activation='relu'
    ))
    model.add(BatchNormalization())
    model.add(layers.MaxPooling2D(2, 2))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(
        hp.Int('dense_units', 128, 512, step=128),
        activation='relu'
    ))
    model.add(layers.Dropout(hp.Float('dropout', 0.2, 0.5, step=0.1)))
    model.add(layers.Dense(num_classes, activation='softmax'))
    
    model.compile(
        optimizer=Adam(learning_rate=hp.Float('learning_rate', 1e-5, 1e-2, sampling='log')),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# Initialize the RandomSearch tuner
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=3,
    executions_per_trial=1,
    directory='keras_tuner_dir',
    project_name='HelpTheGreen'
)

print("Starting Hyperparameter Search (3 Trials x 5 Epochs each)...")
tuner.search(train_gen, epochs=5, validation_data=val_gen)
print("Hyperparameter Search Complete.")

# Get the best model and train it for 5 epochs
best_hps = tuner.get_best_hyperparameters(1)[0]
print("\nBest hyperparameters found:")
for param in best_hps.values:
    print(f"{param}: {best_hps.get(param)}")
model = tuner.hypermodel.build(best_hps)

print("\nStarting Final Model Training (50 Epochs)...")
history = model.fit(train_gen, epochs=100, validation_data=val_gen, class_weight=class_weights)

# Save model and class labels locally
model.save('plantvillage_tuned_model.h5')
class_labels = {v: k for k, v in train_gen.class_indices.items()}

with open('class_labels_combined.json', 'w') as f:
    json.dump(class_labels, f)

print("Final tuned model and class labels saved locally.")
# Out:
# Reloading Tuner from keras_tuner_dir\HelpTheGreen\tuner0.json
# Starting Hyperparameter Search (3 Trials x 5 Epochs each)...
# Hyperparameter Search Complete.
#
# Best hyperparameters found:
# conv_1_filters: 64
# conv_2_filters: 256
# conv_3_filters: 256
# dense_units: 384
# dropout: 0.2
# learning_rate: 2.1821838653297958e-05
#
# Starting Final Model Training (50 Epochs)...
# Epoch 1/100
# 627/627 [==============================] - 83s 112ms/step - loss: 1.0166 - accuracy: 0.5976 - val_loss: 0.6119 - val_accuracy: 0.6701
# Epoch 2/100
# 627/627 [==============================] - 47s 75ms/step - loss: 0.6748 - accuracy: 0.6379 - val_loss: 0.5870 - val_accuracy: 0.6998
# Epoch 3/100
# 627/627 [==============================] - 59s 94ms/step - loss: 0.6049 - accuracy: 0.6766 - val_loss: 0.5905 - val_accuracy: 0.6905
# Epoch 4/100
# 627/627 [==============================] - 57s 90ms/step - loss: 0.5746 - accuracy: 0.6889 - val_loss: 0.6458 - val_accuracy: 0.6645
# Epoch 5/100
# 627/627 [==============================] - 53s 84ms/step - loss: 0.5503 - accuracy: 0.7057 - val_loss: 0.5095 - val_accuracy: 0.7165
# Epoch 6/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0
100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2389 - accuracy: 0.8962 - val_loss: 0.3749 - val_accuracy: 0.8550
# Epoch 81/100
# 627/627 [==============================] - 54s 85ms/step - loss: 0.2287 - accuracy: 0.9024 - val_loss: 0.2813 - val_accuracy: 0.8866
# Epoch 82/100
# 627/627 [==============================] - 55s 87ms/step - loss: 0.2421 - accuracy: 0.8951 - val_loss: 0.2935 - val_accuracy: 0.8801
# Epoch 83/100
# 627/627 [==============================] - 54s 86ms/step - loss: 0.2277 - accuracy: 0.8988 - val_loss: 0.2779 - val_accuracy: 0.9015
# Epoch 84/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2347 - accuracy: 0.8951 - val_loss: 0.2454 - val_accuracy: 0.9024
# Epoch 85/100
# 627/627 [==============================] - 55s 88ms/step - loss: 0.2397 - accuracy: 0.8988 - val_loss: 0.2400 - val_accuracy: 0.9089
# Epoch 86/100
# 627/627 [==============================] - 54s 86ms/step - loss: 0.2271 - accuracy: 0.9020 - val_loss: 0.2441 - val_accuracy: 0.9033
# Epoch 87/100
# 627/627 [==============================] - 56s 89ms/step - loss: 0.2168 - accuracy: 0.9068 - val_loss: 0.2528 - val_accuracy: 0.9024
# Epoch 88/100
# 627/627 [==============================] - 54s 87ms/step - loss: 0.2044 - accuracy: 0.9134 - val_loss: 0.2589 - val_accuracy: 0.8968
# Epoch 89/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2222 - accuracy: 0.9048 - val_loss: 0.2391 - val_accuracy: 0.8968
# Epoch 90/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2192 - accuracy: 0.9094 - val_loss: 0.2557 - val_accuracy: 0.9033
# Epoch 91/100
# 627/627 [==============================] - 54s 86ms/step - loss: 0.2242 - accuracy: 0.9082 - val_loss: 0.2525 - val_accuracy: 0.9080
# Epoch 92/100
# 627/627 [==============================] - 54s 85ms/step - loss: 0.2200 - accuracy: 0.9058 - val_loss: 0.2841 - val_accuracy: 0.8857
# Epoch 93/100
# 627/627 [==============================] - 54s 85ms/step - loss: 0.2087 - accuracy: 0.9112 - val_loss: 0.2228 - val_accuracy: 0.9126
# Epoch 94/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2164 - accuracy: 0.9114 - val_loss: 0.2109 - val_accuracy: 0.9145
# Epoch 95/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2194 - accuracy: 0.9066 - val_loss: 0.3074 - val_accuracy: 0.8838
# Epoch 96/100
# 627/627 [==============================] - 54s 86ms/step - loss: 0.2075 - accuracy: 0.9158 - val_loss: 0.3268 - val_accuracy: 0.8848
# Epoch 97/100
# 627/627 [==============================] - 54s 86ms/step - loss: 0.2037 - accuracy: 0.9110 - val_loss: 0.2496 - val_accuracy: 0.9089
# Epoch 98/100
# 627/627 [==============================] - 54s 86ms/step - loss: 0.1987 - accuracy: 0.9178 - val_loss: 0.2907 - val_accuracy: 0.8885
# Epoch 99/100
# 627/627 [==============================] - 53s 85ms/step - loss: 0.2074 - accuracy: 0.9158 - val_loss: 0.2656 - val_accuracy: 0.9033
# Epoch 100/100
# 627/627 [==============================] - 53s 84ms/step - loss: 0.1958 - accuracy: 0.9178 - val_loss: 0.2490 - val_accuracy: 0.9117
# Final tuned model and class labels saved locally.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 6))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend()
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend()
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')

    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
for epoch in range(len(history.history['accuracy'])):
    print(f"Epoch {epoch+1}:")
    print(f"  Training Accuracy:  {history.history['accuracy'][epoch]:.4f}")
    print(f"  Validation Accuracy:{history.history['val_accuracy'][epoch]:.4f}")
    print(f"  Training Loss:      {history.history['loss'][epoch]:.4f}")
    print(f"  Validation Loss:    {history.history['val_loss'][epoch]:.4f}")
# Out:
# Epoch 1:
#   Training Accuracy:  0.5976
#   Validation Accuracy:0.6701
#   Training Loss:      1.0166
#   Validation Loss:    0.6119
# Epoch 2:
#   Training Accuracy:  0.6379
#   Validation Accuracy:0.6998
#   Training Loss:      0.6748
#   Validation Loss:    0.5870
# Epoch 3:
#   Training Accuracy:  0.6766
#   Validation Accuracy:0.6905
#   Training Loss:      0.6049
#   Validation Loss:    0.5905
# Epoch 4:
#   Training Accuracy:  0.6889
#   Validation Accuracy:0.6645
#   Training Loss:      0.5746
#   Validation Loss:    0.6458
# Epoch 5:
#   Training Accuracy:  0.7057
#   Validation Accuracy:0.7165
#   Training Loss:      0.5503
#   Validation Loss:    0.5095
# Epoch 6:
#   Training Accuracy:  0.7177
#   Validation Accuracy:0.7872
#   Training Loss:      0.5433
#   Validation Loss:    0.4487
# Epoch 7:
#   Training Accuracy:  0.7235
#   Validation Accuracy:0.6961
#   Training Loss:      0.5211
#   Validation Loss:    0.5538
# Epoch 8:
#   Training Accuracy:  0.7384
#   Validation Accuracy:0.6980
#   Training Loss:      0.5023
#   Validation Loss:    0.5510
# Epoch 9:
#   Training Accuracy:  0.7440
#   Validation Accuracy:0.7370
#   Training Loss:      0.5004
#   Validation Loss:    0.5330
# Epoch 10:
#   Training Accuracy:  0.7566
#   Validation Accuracy:0.7519
#   Training Loss:      0.4880
#   Validation Loss:    0.5052
# Epoch 11:
#   Training Accuracy:  0.7524
#   Validation Accuracy:0.7649
#   Training Loss:      0.4821
#   Validation Loss:    0.5125
# Epoch 12:
#   Training Accuracy:  0.7584
#   Validation Accuracy:0.7537
#   Training Loss:      0.4729
#   Validation Loss:    0.4872
# Epoch 13:
#   Training Accuracy:  0.7676
#   Validation Accuracy:0.7500
#   Training Loss:      0.4498
#   Validation Loss:    0.5260
# Epoch 14:
#   Training Accuracy:  0.7616
#   Validation Accuracy:0.7639
#   Training Loss:      0.4609
#   Validation Loss:    0.5041
# Epoch 15:
#   Training Accuracy:  0.7713
#   Validation Accuracy:0.7844
#   Training Loss:      0.4586
#   Validation Loss:    0.4287
# Epoch 16:
#   Training Accuracy:  0.7713
#   Validation Accuracy:0.7723
#   Training Loss:      0.4485
#   Validation Loss:    0.4907
# Epoch 17:
#   Training Accuracy:  0.7696
#   Validation Accuracy:0.7965
#   Training Loss:      0.4504
#   Validation Loss:    0.4596
# Epoch 18:
#   Training Accuracy:  0.7761
#   Validation Accuracy:0.7742
#   Training Loss:      0.4427
#   Validation Loss:    0.4795
# Epoch 19:
#   Training Accuracy:  0.7905
#   Validation Accuracy:0.7760
#   Training Loss:      0.4286
#   Validation Loss:    0.4733
# Epoch 20:
#   Training Accuracy:  0.7867
#   Validation Accuracy:0.7788
#   Training Loss:      0.4292
#   Validation Loss:    0.4477
# Epoch 21:
#   Training Accuracy:  0.7929
#   Validation Accuracy:0.7974
#   Training Loss:      0.4254
#   Validation Loss:    0.4576
# Epoch 22:
#   Training Accuracy:  0.7931
#   Validation Accuracy:0.7175
#   Training Loss:      0.4307
#   Validation Loss:    0.5902
# Epoch 23:
#   Training Accuracy:  0.7911
#   Validation Accuracy:0.7825
#   Training Loss:      0.4216
#   Validation Loss:    0.4759
# Epoch 24:
#   Training Accuracy:  0.7953
#   Validation Accuracy:0.7602
#   Training Loss:      0.4120
#   Validation Loss:    0.4656
# Epoch 25:
#   Training Accuracy:  0.7945
#   Validation Accuracy:0.8002
#   Training Loss:      0.4167
#   Validation Loss:    0.4324
# Epoch 26:
#   Training Accuracy:  0.8043
#   Validation Accuracy:0.7481
#   Training Loss:      0.4093
#   Validation Loss:    0.4790
# Epoch 27:
#   Training Accuracy:  0.8013
#   Validation Accuracy:0.7909
#   Training Loss:      0.4038
#   Validation Loss:    0.4619
# Epoch 28:
#   Training Accuracy:  0.8099
#   Validation Accuracy:0.8058
#   Training Loss:      0.3851
#   Validation Loss:    0.4479
# Epoch 29:
#   Training Accuracy:  0.8109
#   Validation Accuracy:0.7835
#   Training Loss:      0.3981
#   Validation Loss:    0.4430
# Epoch 30:
#   Training Accuracy:  0.8037
#   Validation Accuracy:0.7993
#   Training Loss:      0.4014
#   Validation Loss:    0.4039
# Epoch 31:
#   Training Accuracy:  0.8087
#   Validation Accuracy:0.7965
#   Training Loss:      0.4007
#   Validation Loss:    0.4916
# Epoch 32:
#   Training Accuracy:  0.8103
#   Validation Accuracy:0.7928
#   Training Loss:      0.3823
#   Validation Loss:    0.4337
# Epoch 33:
#   Training Accuracy:  0.8132
#   Validation Accuracy:0.7946
#   Training Loss:      0.3778
#   Validation Loss:    0.5085
# Epoch 34:
#   Training Accuracy:  0.8113
#   Validation Accuracy:0.7909
#   Training Loss:      0.3880
#   Validation Loss:    0.4693
# Epoch 35:
#   Training Accuracy:  0.8119
#   Validation Accuracy:0.7955
#   Training Loss:      0.3864
#   Validation Loss:    0.4110
# Epoch 36:
#   Training Accuracy:  0.8178
#   Validation Accuracy:0.8067
#   Training Loss:      0.3781
#   Validation Loss:    0.4816
# Epoch 37:
#   Training Accuracy:  0.8222
#   Validation Accuracy:0.8095
#   Training Loss:      0.3695
#   Validation Loss:    0.4219
# Epoch 38:
#   Training Accuracy:  0.8214
#   Validation Accuracy:0.8002
#   Training Loss:      0.3665
#   Validation Loss:    0.4731
# Epoch 39:
#   Training Accuracy:  0.8218
#   Validation Accuracy:0.7816
#   Training Loss:      0.3629
#   Validation Loss:    0.4893
# Epoch 40:
#   Training Accuracy:  0.8314
#   Validation Accuracy:0.7639
#   Training Loss:      0.3629
#   Validation Loss:    0.4503
# Epoch 41:
#   Training Accuracy:  0.8254
#   Validation Accuracy:0.8132
#   Training Loss:      0.3564
#   Validation Loss:    0.4655
# Epoch 42:
#   Training Accuracy:  0.8346
#   Validation Accuracy:0.8411
#   Training Loss:      0.3618
#   Validation Loss:    0.3855
# Epoch 43:
#   Training Accuracy:  0.8326
#   Validation Accuracy:0.8123
#   Training Loss:      0.3463
#   Validation Loss:    0.4197
# Epoch 44:
#   Training Accuracy:  0.8300
#   Validation Accuracy:0.8225
#   Training Loss:      0.3576
#   Validation Loss:    0.4197
# Epoch 45:
#   Training Accuracy:  0.8366
#   Validation Accuracy:0.8113
#   Training Loss:      0.3402
#   Validation Loss:    0.4262
# Epoch 46:
#   Training Accuracy:  0.8354
#   Validation Accuracy:0.8383
#   Training Loss:      0.3443
#   Validation Loss:    0.3959
# Epoch 47:
#   Training Accuracy:  0.8336
#   Validation Accuracy:0.8299
#   Training Loss:      0.3513
#   Validation Loss:    0.3783
# Epoch 48:
#   Training Accuracy:  0.8408
#   Validation Accuracy:0.8206
#   Training Loss:      0.3417
#   Validation Loss:    0.4032
# Epoch 49:
#   Training Accuracy:  0.8332
#   Validation Accuracy:0.8327
#   Training Loss:      0.3408
#   Validation Loss:    0.3189
# Epoch 50:
#   Training Accuracy:  0.8432
#   Validation Accuracy:0.8216
#   Training Loss:      0.3305
#   Validation Loss:    0.4351
# Epoch 51:
#   Training Accuracy:  0.8490
#   Validation Accuracy:0.8578
#   Training Loss:      0.3230
#   Validation Loss:    0.3362
# Epoch 52:
#   Training Accuracy:  0.8482
#   Validation Accuracy:0.8327
#   Training Loss:      0.3200
#   Validation Loss:    0.3732
# Epoch 53:
#   Training Accuracy:  0.8563
#   Validation Accuracy:0.8457
#   Training Loss:      0.3181
#   Validation Loss:    0.3596
# Epoch 54:
#   Training Accuracy:  0.8516
#   Validation Accuracy:0.8318
#   Training Loss:      0.3214
#   Validation Loss:    0.3863
# Epoch 55:
#   Training Accuracy:  0.8585
#   Validation Accuracy:0.8281
#   Training Loss:      0.3212
#   Validation Loss:    0.3699
# Epoch 56:
#   Training Accuracy:  0.8635
#   Validation Accuracy:0.8420
#   Training Loss:      0.3098
#   Validation Loss:    0.3340
# Epoch 57:
#   Training Accuracy:  0.8623
#   Validation Accuracy:0.8383
#   Training Loss:      0.2958
#   Validation Loss:    0.3788
# Epoch 58:
#   Training Accuracy:  0.8587
#   Validation Accuracy:0.8615
#   Training Loss:      0.3051
#   Validation Loss:    0.3278
# Epoch 59:
#   Training Accuracy:  0.8611
#   Validation Accuracy:0.8327
#   Training Loss:      0.3010
#   Validation Loss:    0.4027
# Epoch 60:
#   Training Accuracy:  0.8671
#   Validation Accuracy:0.8569
#   Training Loss:      0.2921
#   Validation Loss:    0.3490
# Epoch 61:
#   Training Accuracy:  0.8657
#   Validation Accuracy:0.8374
#   Training Loss:      0.2953
#   Validation Loss:    0.4986
# Epoch 62:
#   Training Accuracy:  0.8697
#   Validation Accuracy:0.8513
#   Training Loss:      0.2946
#   Validation Loss:    0.3333
# Epoch 63:
#   Training Accuracy:  0.8665
#   Validation Accuracy:0.8671
#   Training Loss:      0.2929
#   Validation Loss:    0.3349
# Epoch 64:
#   Training Accuracy:  0.8737
#   Validation Accuracy:0.8606
#   Training Loss:      0.2743
#   Validation Loss:    0.3577
# Epoch 65:
#   Training Accuracy:  0.8691
#   Validation Accuracy:0.8606
#   Training Loss:      0.2788
#   Validation Loss:    0.3268
# Epoch 66:
#   Training Accuracy:  0.8715
#   Validation Accuracy:0.8783
#   Training Loss:      0.2847
#   Validation Loss:    0.2928
# Epoch 67:
#   Training Accuracy:  0.8789
#   Validation Accuracy:0.8755
#   Training Loss:      0.2719
#   Validation Loss:    0.3040
# Epoch 68:
#   Training Accuracy:  0.8805
#   Validation Accuracy:0.8494
#   Training Loss:      0.2773
#   Validation Loss:    0.3418
# Epoch 69:
#   Training Accuracy:  0.8829
#   Validation Accuracy:0.8625
#   Training Loss:      0.2657
#   Validation Loss:    0.3859
# Epoch 70:
#   Training Accuracy:  0.8873
#   Validation Accuracy:0.8652
#   Training Loss:      0.2653
#   Validation Loss:    0.3280
# Epoch 71:
#   Training Accuracy:  0.8849
#   Validation Accuracy:0.8820
#   Training Loss:      0.2600
#   Validation Loss:    0.3616
# Epoch 72:
#   Training Accuracy:  0.8957
#   Validation Accuracy:0.8262
#   Training Loss:      0.2483
#   Validation Loss:    0.5615
# Epoch 73:
#   Training Accuracy:  0.8837
#   Validation Accuracy:0.8941
#   Training Loss:      0.2689
#   Validation Loss:    0.2941
# Epoch 74:
#   Training Accuracy:  0.8889
#   Validation Accuracy:0.8903
#   Training Loss:      0.2496
#   Validation Loss:    0.2689
# Epoch 75:
#   Training Accuracy:  0.8879
#   Validation Accuracy:0.8717
#   Training Loss:      0.2473
#   Validation Loss:    0.3174
# Epoch 76:
#   Training Accuracy:  0.8929
#   Validation Accuracy:0.8810
#   Training Loss:      0.2470
#   Validation Loss:    0.3004
# Epoch 77:
#   Training Accuracy:  0.8899
#   Validation Accuracy:0.8810
#   Training Loss:      0.2582
#   Validation Loss:    0.2671
# Epoch 78:
#   Training Accuracy:  0.8871
#   Validation Accuracy:0.9136
#   Training Loss:      0.2590
#   Validation Loss:    0.2080
# Epoch 79:
#   Training Accuracy:  0.8945
#   Validation Accuracy:0.9071
#   Training Loss:      0.2411
#   Validation Loss:    0.2215
# Epoch 80:
#   Training Accuracy:  0.8962
#   Validation Accuracy:0.8550
#   Training Loss:      0.2389
#   Validation Loss:    0.3749
# Epoch 81:
#   Training Accuracy:  0.9024
#   Validation Accuracy:0.8866
#   Training Loss:      0.2287
#   Validation Loss:    0.2813
# Epoch 82:
#   Training Accuracy:  0.8951
#   Validation Accuracy:0.8801
#   Training Loss:      0.2421
#   Validation Loss:    0.2935
# Epoch 83:
#   Training Accuracy:  0.8988
#   Validation Accuracy:0.9015
#   Training Loss:      0.2277
#   Validation Loss:    0.2779
# Epoch 84:
#   Training Accuracy:  0.8951
#   Validation Accuracy:0.9024
#   Training Loss:      0.2347
#   Validation Loss:    0.2454
# Epoch 85:
#   Training Accuracy:  0.8988
#   Validation Accuracy:0.9089
#   Training Loss:      0.2397
#   Validation Loss:    0.2400
# Epoch 86:
#   Training Accuracy:  0.9020
#   Validation Accuracy:0.9033
#   Training Loss:      0.2271
#   Validation Loss:    0.2441
# Epoch 87:
#   Training Accuracy:  0.9068
#   Validation Accuracy:0.9024
#   Training Loss:      0.2168
#   Validation Loss:    0.2528
# Epoch 88:
#   Training Accuracy:  0.9134
#   Validation Accuracy:0.8968
#   Training Loss:      0.2044
#   Validation Loss:    0.2589
# Epoch 89:
#   Training Accuracy:  0.9048
#   Validation Accuracy:0.8968
#   Training Loss:      0.2222
#   Validation Loss:    0.2391
# Epoch 90:
#   Training Accuracy:  0.9094
#   Validation Accuracy:0.9033
#   Training Loss:      0.2192
#   Validation Loss:    0.2557
# Epoch 91:
#   Training Accuracy:  0.9082
#   Validation Accuracy:0.9080
#   Training Loss:      0.2242
#   Validation Loss:    0.2525
# Epoch 92:
#   Training Accuracy:  0.9058
#   Validation Accuracy:0.8857
#   Training Loss:      0.2200
#   Validation Loss:    0.2841
# Epoch 93:
#   Training Accuracy:  0.9112
#   Validation Accuracy:0.9126
#   Training Loss:      0.2087
#   Validation Loss:    0.2228
# Epoch 94:
#   Training Accuracy:  0.9114
#   Validation Accuracy:0.9145
#   Training Loss:      0.2164
#   Validation Loss:    0.2109
# Epoch 95:
#   Training Accuracy:  0.9066
#   Validation Accuracy:0.8838
#   Training Loss:      0.2194
#   Validation Loss:    0.3074
# Epoch 96:
#   Training Accuracy:  0.9158
#   Validation Accuracy:0.8848
#   Training Loss:      0.2075
#   Validation Loss:    0.3268
# Epoch 97:
#   Training Accuracy:  0.9110
#   Validation Accuracy:0.9089
#   Training Loss:      0.2037
#   Validation Loss:    0.2496
# Epoch 98:
#   Training Accuracy:  0.9178
#   Validation Accuracy:0.8885
#   Training Loss:      0.1987
#   Validation Loss:    0.2907
# Epoch 99:
#   Training Accuracy:  0.9158
#   Validation Accuracy:0.9033
#   Training Loss:      0.2074
#   Validation Loss:    0.2656
# Epoch 100:
#   Training Accuracy:  0.9178
#   Validation Accuracy:0.9117
#   Training Loss:      0.1958
#   Validation Loss:    0.2490

# %%
from sklearn.metrics import confusion_matrix, classification_report # type: ignore
import seaborn as sns # type: ignore

# 1. Get True Labels and Predictions from the Validation Set
print("Generating predictions on validation set...")

# Reset generator to ensure it starts from the beginning
val_gen.reset() 

# Predict the categories for all validation images
# steps = total number of validation samples / batch size
val_steps = val_gen.samples // val_gen.batch_size 
if val_gen.samples % val_gen.batch_size != 0:
    val_steps += 1
    
Y_pred = model.predict(val_gen, steps=val_steps)
y_pred_classes = np.argmax(Y_pred, axis=1) # Predicted classes (e.g., 0, 1)

# Get true classes (ensure generator is not shuffled)
y_true = val_gen.classes # True classes (e.g., 0, 1)

# Get class labels from the generator
class_names = list(train_gen.class_indices.keys())

# 2. Compute Confusion Matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)

# 3. Print Classification Report (Precision, Recall, F1-score)
print("\n--- Classification Report ---")
print(classification_report(y_true, y_pred_classes, target_names=class_names))

# 4. Plot Confusion Matrix (for report visualization)
plt.figure(figsize=(8, 6))
sns.heatmap(
    conf_matrix, 
    annot=True, 
    fmt='d', 
    cmap='Blues', 
    xticklabels=class_names, 
    yticklabels=class_names
)
plt.title('Confusion Matrix for CNN Model')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
# Out:
# Generating predictions on validation set...
# 135/135 [==============================] - 5s 33ms/step
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#     diseased       0.56      0.51      0.53       614
#      healthy       0.41      0.45      0.43       462
#
#     accuracy                           0.49      1076
#    macro avg       0.48      0.48      0.48      1076
# weighted avg       0.49      0.49      0.49      1076

# %%
# ===== FIND OPTIMAL THRESHOLD =====
from sklearn.metrics import precision_recall_curve, roc_curve, auc
import matplotlib.pyplot as plt

# Get probability predictions for healthy class (index 1)
val_gen.reset()
y_proba = model.predict(val_gen, steps=val_steps)[:, 1]  # Probabilities for "healthy"

# Calculate precision-recall curve
precisions, recalls, thresholds = precision_recall_curve(y_true, y_proba)

# Plot Precision-Recall Curve
plt.figure(figsize=(10, 6))
plt.plot(thresholds, precisions[:-1], 'b-', label='Precision')
plt.plot(thresholds, recalls[:-1], 'r-', label='Recall')
plt.xlabel('Threshold')
plt.ylabel('Score')
plt.title('Precision-Recall vs Threshold')
plt.legend()
plt.grid(True)
plt.show()

# Find optimal threshold (where precision and recall are balanced)
f1_scores = 2 * (precisions * recalls) / (precisions + recalls + 1e-10)
optimal_idx = np.argmax(f1_scores[:-1])
optimal_threshold = thresholds[optimal_idx]

print(f"\n✅ Optimal Threshold: {optimal_threshold:.4f}")
print(f"   - Precision: {precisions[optimal_idx]:.2%}")
print(f"   - Recall: {recalls[optimal_idx]:.2%}")
print(f"   - F1-Score: {f1_scores[optimal_idx]:.2%}")

# Calculate ROC-AUC
fpr, tpr, _ = roc_curve(y_true, y_proba)
roc_auc = auc(fpr, tpr)

# Plot ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

print(f"\n📊 ROC-AUC Score: {roc_auc:.4f}")
# Out:
# 135/135 [==============================] - 5s 36ms/step
# ✅ Optimal Threshold: 0.0000
#    - Precision: 42.94%
#    - Recall: 100.00%
#    - F1-Score: 60.08%
# 📊 ROC-AUC Score: 0.5068

# %%
import numpy as np
from PIL import Image
from tensorflow.keras.models import load_model # type: ignore
model = load_model('plantvillage_tuned_model.h5')
def quick_predict(image_path):
     img = Image.open(image_path).convert("RGB").resize((128, 128))
     arr = np.expand_dims(np.array(img, dtype='float32') / 255.0, axis=0)
     pred = model.predict(arr, verbose=0)[0]
     if pred[1] < 0.35:
          return "🔴 DISEASED"
     return "🟢 HEALTHY"
# Test on your image
print(quick_predict(r"C:\Users\majum\OneDrive\Desktop\images (2).jpeg"))
# Out:
# 🟢 HEALTHY
